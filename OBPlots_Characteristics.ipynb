# %%
import pandas as pd

# %%
OrderBookPlots_df = pd.read_csv('./resources/OrderLog20020812_OBP.csv')
OrderBookPlots_df
# Out:
#        Unnamed: 0     NO       SECCODE BUYSELL       TIME  ORDERNO  ACTION  \
# 0               0      1  RU14VOST1005       S  103000000        1       1
# 1               1      2  RU0009071187       S  103000000        2       1
# 2               2      3  RU14VOST1005       S  103000000        3       1
# 3               3      4  RU0009100762       B  103000000        4       1
# 4               4      5  RU0009054449       S  103000000        5       1
# ...           ...    ...           ...     ...        ...      ...     ...
# 90739       90739  90740  RU14TATN3006       B  184557000    38574       1
# 90740       90740  90741  RU14VOST1005       S  184558000    38559       0
# 90741       90741  90742  RU0009046700       S  184559000    38575       1
# 90742       90742  90743  RU0009071187       B  184559000    38550       0
# 90743       90743  90744  RU0009046700       B  184600000    38534       0
#
#          PRICE  VOLUME  TRADENO  TRADEPRICE  OBPLOTNO
# ...

# %%
class OBPpots_df2OBPlots_Characteristics_df:
    def __init__(self, OrderBookPlots_df):
        self.OrderBookPlots_df = OrderBookPlots_df
