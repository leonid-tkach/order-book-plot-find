# %%
import pandas as pd

# %%
tinyuf_df = pd.read_csv('./resources/Lukoil 2002 OrderLog.txt')
tinyuf_df.head()
# Out:
#        DATE  NO       SECCODE BUYSELL       TIME  ORDERNO  ACTION   PRICE  \
# 0  20020812  24  RU0009024277       S  103000000       24       1  610.00
# 1  20020812  26  RU0009024277       S  103000000       26       1  529.99
# 2  20020812  28  RU0009024277       B  103000000       28       1  415.00
# 3  20020812  54  RU0009024277       S  103000000       54       1  560.00
# 4  20020812  57  RU0009024277       S  103000000       57       1  570.00
#
#    VOLUME  TRADENO  TRADEPRICE
# 0     400      NaN         NaN
# 1      50      NaN         NaN
# 2     300      NaN         NaN
# 3     200      NaN         NaN
# 4     200      NaN         NaN
